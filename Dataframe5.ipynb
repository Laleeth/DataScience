# %%
import pandas  as pd

# %%
import numpy as np
df = pd.read_csv("geo.csv")
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df1 = pd.read_csv("torn.csv")
df1.head()
# Out:
#    Unnamed: 0 Postalcode      Borough                            Neighborhood
# 0           0        M1B  Scarborough                          Rouge, Malvern
# 1           1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2           2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3           3        M1G  Scarborough                                  Woburn
# 4           4        M1H  Scarborough                               Cedarbrae

# %%
df1.drop('Unnamed: 0',axis=1).head()
# Out:
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
df2 = pd.concat([df,df1],axis=1, sort=False)
df2.head()
# Out:
#   Postal Code   Latitude  Longitude  Unnamed: 0 Postalcode      Borough  \
# 0         M1B  43.806686 -79.194353           0        M1B  Scarborough
# 1         M1C  43.784535 -79.160497           1        M1C  Scarborough
# 2         M1E  43.763573 -79.188711           2        M1E  Scarborough
# 3         M1G  43.770992 -79.216917           3        M1G  Scarborough
# 4         M1H  43.773136 -79.239476           4        M1H  Scarborough
#
#                              Neighborhood
# 0                          Rouge, Malvern
# 1  Highland Creek, Rouge Hill, Port Union
# 2       Guildwood, Morningside, West Hill
# 3                                  Woburn
# 4                               Cedarbrae

# %%
df2.drop('Postal Code',axis=1,inplace=True)

# %%
df2.head()
# Out:
#     Latitude  Longitude Postalcode      Borough  \
# 0  43.806686 -79.194353        M1B  Scarborough
# 1  43.784535 -79.160497        M1C  Scarborough
# 2  43.763573 -79.188711        M1E  Scarborough
# 3  43.770992 -79.216917        M1G  Scarborough
# 4  43.773136 -79.239476        M1H  Scarborough
#
#                              Neighborhood
# 0                          Rouge, Malvern
# 1  Highland Creek, Rouge Hill, Port Union
# 2       Guildwood, Morningside, West Hill
# 3                                  Woburn
# 4                               Cedarbrae

# %%
df3 = df2.reindex(columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-1ac53c300ae4> in <module>
# ----> 1 df3 = df2.reindex(index='Postalcode')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3807         kwargs.pop('axis', None)
#    3808         kwargs.pop('labels', None)
# -> 3809         return super(DataFrame, self).reindex(**kwargs)
#    3810
#    3811     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
# ...
